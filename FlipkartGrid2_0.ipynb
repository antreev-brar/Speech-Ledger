# %% [markdown]
# <a href="https://colab.research.google.com/github/antreev-brar/FlipkartGrid/blob/master/FlipkartGrid2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Mounting Google Drive (as data doesnt get stored on Colab ROM)***

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
# %cd gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive

# %% [markdown]
# ***Cloning the repo***

# %%
# !git clone https://github.com/antreev-brar/FlipkartGrid.git
# Out:
# Cloning into 'FlipkartGrid'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 341 (delta 91), reused 118 (delta 35), pack-reused 154
# Receiving objects: 100% (341/341), 76.66 MiB | 20.78 MiB/s, done.
# Resolving deltas: 100% (117/117), done.

# %%
# %cd FlipkartGrid/
# Out:
# /content/gdrive/My Drive/FlipkartGrid

# %%
# !ls
# Out:
# assets	LICENSE  README.md  Speaker-Diarization   wav
# DTLN	mp3	 run.sh     transcription_api.py

# %% [markdown]
# ***Dependencies required in Colab (rest are already there)***

# %%
# !pip install soundfile

# %%
# !pip install pydub

# %%
# !pip install wavinfo

# %%
# !apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libportaudio2 is already the newest version (19.6.0-1).
# libportaudiocpp0 is already the newest version (19.6.0-1).
# portaudio19-dev is already the newest version (19.6.0-1).
# libasound2-dev is already the newest version (1.1.3-5ubuntu0.5).
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# !pip install pyaudio

# %%
# !pip install tensorflow==2.0.0-alpha0
# Out:
# ...
#      |████████████████████████████████| 79.9MB 38kB/s
# ...
#      |████████████████████████████████| 3.0MB 51.8MB/s
# ...
#      |████████████████████████████████| 419kB 48.0MB/s
# ...
#   Found existing installation: tensorflow 2.0.0
#     Uninstalling tensorflow-2.0.0:
#       Successfully uninstalled tensorflow-2.0.0
# ...

# %%
# !pip install keras==2.3.1
# Out:
# ...
#      |████████████████████████████████| 378kB 4.8MB/s
# ...
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# ...

# %% [markdown]
# ***Granting execution rights for bash script***

# %%
# !chmod u+x run.sh

# %%
# !pwd
# !ls
# Out:
# /content/gdrive/My Drive/FlipkartGrid
# assets	LICENSE  README.md  Speaker-Diarization   wav
# DTLN	mp3	 run.sh     transcription_api.py

# %% [markdown]
# ***Script Execution***

# %%
# !./run.sh mp3
# Out:
# /content/gdrive/My Drive/FlipkartGrid/mp3 /content/gdrive/My Drive/FlipkartGrid
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %% [markdown]
# ***Navigate to gdrive to view output files (audio and transcriptions)***
